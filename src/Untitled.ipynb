# %%
from lol_spring_player_power import create_player_rankings
from lol_spring_player_power import df
from mid_season import create_mid_player_rankings
from mid_season import new_df

# %%
old_dfs=create_player_rankings(df)
old_dfs
old_top=old_dfs[0]
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:3939: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(obj)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:2994: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(result)

# %%
old_top
# Out:
#               Top [TSM Huni]  Top [C9 Summit]  Top [TL Bwipo]  \
# Name
# Johann                   4.0              1.0             2.0
# Milad                    4.0              1.0             2.0
# Tak                      4.0              1.0             2.0
# Joimes                   7.0              2.0             4.0
# Zain                     3.0              1.0             2.0
# Average Rank             4.4              1.2             2.4
# Highest                  7.0              2.0             4.0
# Lowest                   3.0              1.0             2.0
#
#               Top [100T Ssumday]  Top [EG Impact]  Top [GGS Licorice]  \
# Name
# Johann                       5.0              3.0                 8.0
# Milad                        5.0              3.0                 6.0
# Tak                          8.0              3.0                 5.0
# Joimes                       1.0              3.0                 5.0
# ...

# %%
x=old_top.loc['Average Rank']
x
# Out:
# Top [TSM Huni]        4.4
# Top [C9 Summit]       1.2
# Top [TL Bwipo]        2.4
# Top [100T Ssumday]    4.8
# Top [EG Impact]       3.2
# Top [GGS Licorice]    6.2
# Top [FLY Kumo]        9.2
# Top [CLG Jenkins]     8.0
# Top [IMT Revenge]     7.4
# Top [DIG FakeGod]     8.2
# Name: Average Rank, dtype: float64

# %%
new_dfs=create_mid_player_rankings(new_df)
# Out:
# |                    |   Johann |   Milad |   Tak |   Joimes |   Zain |   Kwan |   Average Rank |   Lowest |   Highest |
# |:-------------------|---------:|--------:|------:|---------:|-------:|-------:|---------------:|---------:|----------:|
# | Top [C9 Summit]    |        2 |       1 |     1 |        1 |      2 |      3 |        1.66667 |        3 |         1 |
# | Top [TL Bwipo]     |        1 |       2 |     2 |        3 |      1 |      1 |        1.66667 |        3 |         1 |
# | Top [100T Ssumday] |        4 |       3 |     4 |        4 |      3 |      2 |        3.33333 |        4 |         2 |
# | Top [EG Impact]    |        3 |       4 |     3 |        2 |      4 |      6 |        3.66667 |        6 |         2 |
# | Top [IMT Revenge]  |        5 |       5 |     6 |        6 |      5 |      8 |        5.83333 |        8 |         5 |
# | Top [GGS Licorice] |        7 |       6 |     7 |        5 |     10 |      5 |        6.66667 |       10 |         5 |
# ...

# %%
new_dfs
# Out:
# [              Top [TSM Huni]  Top [C9 Summit]  Top [TL Bwipo]  \
#  Name
#  Johann              6.000000         2.000000        1.000000
#  Milad               8.000000         1.000000        2.000000
#  Tak                 5.000000         1.000000        2.000000
#  Joimes              7.000000         1.000000        3.000000
#  Zain                8.000000         2.000000        1.000000
#  Kwan               10.000000         3.000000        1.000000
#  Average Rank        7.333333         1.666667        1.666667
#  Lowest             10.000000         3.000000        3.000000
#  Highest             5.000000         1.000000        1.000000
#
#                Top [100T Ssumday]  Top [EG Impact]  Top [GGS Licorice]  \
#  Name
#  Johann                  4.000000         3.000000            7.000000
#  Milad                   3.000000         4.000000            6.000000
#  Tak                     4.000000         3.000000            7.000000
# ...

# %%
new_dfs[0]
new_top=new_dfs[0]

# %%
new_top=new_top.round(1)
new_top
# Out:
#               Top [TSM Huni]  Top [C9 Summit]  Top [TL Bwipo]  \
# Name
# Johann                   6.0              2.0             1.0
# Milad                    8.0              1.0             2.0
# Tak                      5.0              1.0             2.0
# Joimes                   7.0              1.0             3.0
# Zain                     8.0              2.0             1.0
# Kwan                    10.0              3.0             1.0
# Average Rank             7.3              1.7             1.7
# Lowest                  10.0              3.0             3.0
# Highest                  5.0              1.0             1.0
#
#               Top [100T Ssumday]  Top [EG Impact]  Top [GGS Licorice]  \
# Name
# Johann                       4.0              3.0                 7.0
# Milad                        3.0              4.0                 6.0
# Tak                          4.0              3.0                 7.0
# ...

# %%
old_top
# Out:
#               Top [TSM Huni]  Top [C9 Summit]  Top [TL Bwipo]  \
# Name
# Johann                   4.0              1.0             2.0
# Milad                    4.0              1.0             2.0
# Tak                      4.0              1.0             2.0
# Joimes                   7.0              2.0             4.0
# Zain                     3.0              1.0             2.0
# Average Rank             4.4              1.2             2.4
# Highest                  7.0              2.0             4.0
# Lowest                   3.0              1.0             2.0
#
#               Top [100T Ssumday]  Top [EG Impact]  Top [GGS Licorice]  \
# Name
# Johann                       5.0              3.0                 8.0
# Milad                        5.0              3.0                 6.0
# Tak                          8.0              3.0                 5.0
# Joimes                       1.0              3.0                 5.0
# ...

# %%
test_diff=new_top.loc['Average Rank']-old_top.loc['Average Rank']

# %%
test_diff
# Out:
# Top [TSM Huni]        2.9
# Top [C9 Summit]       0.5
# Top [TL Bwipo]       -0.7
# Top [100T Ssumday]   -1.5
# Top [EG Impact]       0.5
# Top [GGS Licorice]    0.5
# Top [FLY Kumo]       -1.2
# Top [CLG Jenkins]     0.2
# Top [IMT Revenge]    -1.6
# Top [DIG FakeGod]     0.5
# Name: Average Rank, dtype: float64

# %%
old_dfs[0].loc['Average Rank']
# Out:
# Top [TSM Huni]        4.4
# Top [C9 Summit]       1.2
# Top [TL Bwipo]        2.4
# Top [100T Ssumday]    4.8
# Top [EG Impact]       3.2
# Top [GGS Licorice]    6.2
# Top [FLY Kumo]        9.2
# Top [CLG Jenkins]     8.0
# Top [IMT Revenge]     7.4
# Top [DIG FakeGod]     8.2
# Name: Average Rank, dtype: float64
